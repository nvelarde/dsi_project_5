# %%
from lib.project_5 import general_process, load_data_from_database, make_data_dict, general_model, general_transformer
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV, cross_val_score
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from __future__ import print_function
from collections import defaultdict

pd.set_option("display.max_columns", 999)
pd.set_option("display.max_rows", 999)

pd.set_option('precision', 5)

# %% [markdown]
# # Step 1 - Benchmarking

# %% [markdown]
# **NOTE: EACH OF THESE SHOULD BE WRITTEN SOLELY WITH REGARD TO STEP 1 - BENCHMARKING**
#
# ### Domain and Data
#
# **TODO:** Write a simple statement about the domain of your problem and the dataset upon which you will be working.
#
# ### Problem Statement
#
# **TODO:** Write a simple problem statement with regard to benchmarking your work only.
#
# ### Solution Statement
#
# **TODO:** Write a simple solution statement with regard to benchmarking your work only.
#
# ### Metric
#
# **TODO**: Write a statement about the metric you will be using. This section is global as it will be the metric you will use throughout this project. Provide a brief justification for choosing this metric.
#
# ### Benchmark
#
# **TODO**: Write a statement explaining that this is the process by which you identify a benchmark for your project.

# %% [markdown]
# ## Implementation
#
# Implement the following code pipeline using the functions you write in `lib/project_5.py`.

# %% [markdown]
# <img src="assets/benchmarking.png" width="600px">

# %%
madelon_df = load_data_from_database()

# %%
madelon_df.head()
# Out:
#    index  feat_000  feat_001  feat_002  feat_003  feat_004  feat_005  \
# 0      0       485       477       537       479       452       471
# 1      1       483       458       460       487       587       475
# 2      2       487       542       499       468       448       471
# 3      3       480       491       510       485       495       472
# 4      4       484       502       528       489       466       481
#
#    feat_006  feat_007  feat_008  feat_009  feat_010  feat_011  feat_012  \
# 0       491       476       475       473       455       500       456
# 1       526       479       485       469       434       483       465
# 2       442       478       480       477       468       497       477
# 3       417       474       502       476       455       520       437
# 4       402       478       487       468       432       494       493
#
#    feat_013  feat_014  feat_015  feat_016  feat_017  feat_018  feat_019  \
# 0       507       478       491       447       422       480       482
# 1       503       472       478       469       518       495       491
# 2       491       493       502       465       567       510       475
# 3       472       481       436       503       522       488       468
# 4       434       505       497       486       471       467       476
#
#    feat_020  feat_021  feat_022  feat_023  feat_024  feat_025  feat_026  \
# 0       515       482       464       484       477       496       509
# 1       478       530       462       494       549       469       516
# 2       474       483       490       492       544       482       454
# 3       492       488       476       479       477       485       506
# 4       455       517       483       465       512       552       505
#
#    feat_027  feat_028  feat_029  feat_030  feat_031  feat_032  feat_033  \
# 0       491       459       482       483       505       508       458
# 1       487       475       486       478       514       542       406
# 2       496       491       495       476       438       489       432
# 3       476       472       506       479       472       504       553
# 4       464       472       419       479       543       491       488
#
#    feat_034  feat_035  feat_036  feat_037  feat_038  feat_039  feat_040  \
# 0       509       517       479       487       473       472       474
# 1       469       452       483       498       480       476       474
# 2       486       512       475       476       480       476       477
# 3       492       494       464       448       486       476       475
# 4       446       563       471       457       475       478       473
#
#    feat_041  feat_042  feat_043  feat_044  feat_045  feat_046  feat_047  \
# 0       531       485       508       517       489       507       515
# 1       504       478       493       472       461       521       521
# 2       516       454       486       459       493       472       455
# 3       438       448       464       487       484       509       464
# 4       539       469       481       543       499       464       497
#
#    feat_048  feat_049  feat_050  feat_051  feat_052  feat_053  feat_054  \
# 0       440       465       550       532       450       483       460
# 1       499       458       466       519       487       485       489
# 2       460       449       493       562       454       486       468
# 3       529       465       550       420       500       482       495
# 4       429       499       523       527       508       480       457
#
#    feat_055  feat_056  feat_057  feat_058  feat_059  feat_060  feat_061  \
# 0       469       507       485       479       458       516       480
# 1       485       551       516       435       487       525       481
# 2       525       524       487       531       475       479       486
# 3       478       477       489       586       505       485       484
# 4       493       539       474       497       483       483       487
#
#    feat_062  feat_063  feat_064  feat_065  feat_066  feat_067  feat_068  \
# 0       460       479       648       480       561       481       474
# 1       529       486       488       513       415       463       481
# 2       449       478       485       504       564       468       482
# 3       531       479       415       507       478       485       478
# 4       443       492       387       536       542       489       484
#
#    feat_069  feat_070  feat_071  feat_072  feat_073  feat_074  feat_075  \
# 0       474       544       484       490       451       494       480
# 1       481       491       504       496       433       475       416
# 2       475       548       508       488       542       475       527
# 3       474       574       486       410       501       469       534
# 4       481       527       472       510       523       488       482
#
#    feat_076  feat_077  feat_078  feat_079  feat_080  feat_081  feat_082  \
# 0       486       459       521       500       466       457       494
# 1       481       482       493       536       483       416       553
# 2       466       424       486       450       531       542       467
# 3       483       468       475       499       489       565       500
# 4       481       487       510       479       516       499       544
#
#    feat_083  feat_084  feat_085  feat_086  feat_087  feat_088  feat_089  \
# 0       492       488       497       477       461       473       464
# 1       460       554       447       477       499       470       527
# 2       459       523       516       478       492       475       477
# 3       490       482       419       484       500       476       505
# 4       492       474       477       483       493       470       571
#
#    feat_090  feat_091  feat_092  feat_093  feat_094  feat_095  feat_096  \
# 0       476       471       481       507       474       500       481
# 1       476       480       507       522       474       485       478
# 2       476       545       506       492       483       500       476
# 3       476       495       473       499       472       482       480
# 4       477       489       534       505       476       508       484
#
#    feat_097  feat_098  feat_099  feat_100  feat_101  feat_102  feat_103  \
# 0       536       464       501       479       480       483       462
# 1       479       468       397       482       469       477       476
# 2       473       494       474       494       487       487       455
# 3       488       466       434       494       496       482       483
# 4       496       496       509       466       476       486       480
#
#    feat_104  feat_105  feat_106  feat_107  feat_108  feat_109  feat_110  \
# 0       470       181       510       470       431       482       496
# 1       553       431       489       447       535       487       488
# 2       457       593       460       527       479       485       469
# 3       479       698       492       463       521       469       498
# 4       478       451       487       487       534       471       487
#
#    feat_111  feat_112  feat_113  feat_114  feat_115  feat_116  feat_117  \
# 0       481       469       539       491       482       481       476
# 1       557       485       515       484       497       479       494
# 2       509       484       484       500       464       488       497
# 3       475       481       507       410       477       505       468
# 4       402       472       441       482       477       479       486
#
#    feat_118  feat_119  feat_120  feat_121  feat_122  feat_123  feat_124  \
# 0       533       495       474       485       479       495       465
# 1       436       470       477       468       480       587       503
# 2       489       490       475       435       486       417       472
# 3       487       508       472       445       490       454       470
# 4       543       491       482       475       480       477       410
#
#    feat_125  feat_126  feat_127  feat_128  feat_129  feat_130  feat_131  \
# 0       541       493       488       452       481       491       501
# 1       429       496       502       473       485       522       484
# 2       513       487       504       487       444       541       520
# 3       478       465       515       493       494       487       501
# 4       516       483       523       475       531       467       478
#
#    feat_132  feat_133  feat_134  feat_135  feat_136  feat_137  feat_138  \
# 0       477       479       503       529       540       504       482
# 1       481       486       519       455       442       499       470
# 2       505       482       453       473       525       472       471
# 3       524       485       476       473       458       458       481
# 4       453       479       451       586       564       485       481
#
#    feat_139  feat_140  feat_141  feat_142  feat_143  feat_144  feat_145  \
# 0       463       477       530       508       488       488       474
# 1       483       508       510       481       494       483       473
# 2       513       525       513       487       467       492       478
# 3       462       481       624       483       483       485       491
# 4       485       497       486       463       474       480       480
#
#    feat_146  feat_147  feat_148  feat_149  feat_150  feat_151  feat_152  \
# 0       479       506       478       511       501       474       483
# 1       481       510       480       447       538       497       475
# 2       480       485       485       497       550       491       493
# 3       477       482       481       494       500       456       482
# 4       482       479       479       411       480       485       466
#
#    feat_153  feat_154  feat_155  feat_156  feat_157  feat_158  feat_159  \
# 0       575       478       482       461       480       543       415
# 1       404       479       519       486       492       520       519
# 2       585       478       522       509       458       478       508
# 3       591       478       489       489       493       543       550
# 4       448       479       500       464       494       470       522
#
#    feat_160  feat_161  feat_162  feat_163  feat_164  feat_165  feat_166  \
# 0       527       477       487       486       511       474       477
# 1       500       482       486       487       533       487       476
# 2       462       475       498       487       528       487       475
# 3       474       486       492       472       456       499       477
# 4       475       491       477       478       402       475       476
#
#    feat_167  feat_168  feat_169  feat_170  feat_171  feat_172  feat_173  \
# 0       482       476       516       466       492       561       479
# 1       480       475       459       470       522       489       477
# 2       476       478       432       455       471       518       477
# 3       471       476       439       514       517       495       477
# 4       475       477       487       444       518       470       478
#
#    feat_174  feat_175  feat_176  feat_177  feat_178  feat_179  feat_180  \
# 0       472       457       497       475       452       491       477
# 1       447       519       484       472       458       510       529
# 2       475       529       508       474       537       439       513
# 3       462       566       470       477       467       543       516
# 4       469       449       492       485       535       527       480
#
#    feat_181  feat_182  feat_183  feat_184  feat_185  feat_186  feat_187  \
# 0       454       461       472       481       490       526       490
# 1       539       456       478       490       509       481       524
# 2       491       470       499       504       468       532       532
# 3       460       451       483       505       447       456       518
# 4       491       483       495       470       487       472       511
#
#    feat_188  feat_189  feat_190  feat_191  feat_192  feat_193  feat_194  \
# 0       459       478       461       516       511       544       519
# 1       530       478       495       507       459       467       494
# 2       514       487       494       494       482       507       485
# 3       505       478       488       542       512       475       549
# 4       586       475       480       438       454       452       556
#
#    feat_195  feat_196  feat_197  feat_198  feat_199  feat_200  feat_201  \
# 0       487       485       475       477       476       478       470
# 1       470       480       491       476       503       485       475
# 2       487       476       487       476       560       451       502
# 3       480       475       487       474       500       515       470
# 4       479       486       485       475       464       476       480
#
#    feat_202  feat_203  feat_204  feat_205  feat_206  feat_207  feat_208  \
# 0       493       581       484       476       521       474       492
# 1       508       488       495       477       507       482       447
# 2       480       533       472       478       530       476       501
# 3       495       461       464       477       493       477       497
# 4       468       559       508       478       475       477       485
#
#    feat_209  feat_210  feat_211  feat_212  feat_213  feat_214  feat_215  \
# 0       459       487       504       464       485       478       465
# 1       482       483       455       485       474       478       579
# 2       499       505       572       481       463       484       496
# 3       518       474       503       483       519       485       539
# 4       467       480       582       447       445       491       511
#
#    feat_216  feat_217  feat_218  feat_219  feat_220  feat_221  feat_222  \
# 0       603       475       481       491       555       424       528
# 1       540       484       508       480       492       517       490
# 2       466       465       495       471       567       544       513
# 3       535       468       460       477       463       536       459
# 4       484       483       499       486       492       513       468
#
#    feat_223  feat_224  feat_225  feat_226  feat_227  feat_228  feat_229  \
# 0       511       384       525       459       478       477       539
# 1       547       510       465       495       477       475       497
# 2       472       466       475       468       477       475       479
# 3       475       437       524       467       479       475       508
# 4       475       508       515       508       479       476       476
#
#    feat_230  feat_231  feat_232  feat_233  feat_234  feat_235  feat_236  \
# 0       479       508       471       517       482       518       473
# 1       477       442       489       507       466       504       493
# 2       477       485       463       510       503       489       469
# 3       457       495       449       459       480       454       487
# 4       495       489       487       507       500       454       479
#
#    feat_237  feat_238  feat_239  feat_240  feat_241  feat_242  feat_243  \
# 0       478       506       476       507       434       466       480
# 1       471       478       467       530       551       476       470
# 2       480       482       486       505       474       476       501
# 3       482       502       478       502       569       492       463
# 4       481       490       478       478       538       485       489
#
#    feat_244  feat_245  feat_246  feat_247  feat_248  feat_249  feat_250  \
# 0       547       518       516       476       492       454       463
# 1       575       477       510       486       473       504       451
# 2       470       551       477       477       482       557       527
# 3       510       473       486       477       479       491       431
# 4       556       492       478       476       478       477       465
#
#    feat_251  feat_252  feat_253  feat_254  feat_255  feat_256  feat_257  \
# 0       497       477       531       472       495       532       496
# 1       450       477       506       480       506       575       502
# 2       499       476       530       474       473       530       415
# 3       526       478       540       484       488       490       482
# 4       454       477       518       469       446       530       434
#
#    feat_258  feat_259  feat_260  feat_261  feat_262  feat_263  feat_264  \
# 0       492       480       480       479       517       470       470
# 1       486       489       485       479       488       524       465
# 2       486       495       498       478       515       543       475
# 3       486       484       508       487       524       529       481
# 4       507       503       494       473       506       544       497
#
#    feat_265  feat_266  feat_267  feat_268  feat_269  feat_270  feat_271  \
# 0       500       468       477       486       553       490       499
# 1       516       443       503       517       498       482       467
# 2       466       483       484       462       509       477       501
# 3       494       556       500       491       494       471       472
# 4       466       466       491       445       478       507       487
#
#    feat_272  feat_273  feat_274  feat_275  feat_276  feat_277  feat_278  \
# 0       450       469       466       479       476       401       491
# 1       454       407       484       479       475       498       514
# 2       463       477       492       496       476       498       495
# 3       609       505       479       472       477       484       524
# 4       532       529       488       491       476       501       516
#
#    feat_279  feat_280  feat_281  feat_282  feat_283  feat_284  feat_285  \
# 0       551       477       517       492       475       537       516
# 1       492       477       435       491       475       503       480
# 2       473       478       535       485       475       486       522
# 3       475       475       526       470       476       521       433
# 4       532       478       456       497       476       541       502
#
#    feat_286  feat_287  feat_288  feat_289  feat_290  feat_291  feat_292  \
# 0       472       451       484       471       469       523       496
# 1       506       512       482       477       504       527       454
# 2       435       537       473       497       533       461       486
# 3       440       437       478       493       519       482       490
# 4       547       477       480       469       507       498       477
#
#    feat_293  feat_294  feat_295  feat_296  feat_297  feat_298  feat_299  \
# 0       482       458       487       477       457       458       493
# 1       483       458       473       484       542       469       459
# 2       478       429       516       471       468       484       469
# 3       473       517       506       465       502       511       493
# 4       472       465       499       446       508       480       541
#
#    feat_300  feat_301  feat_302  feat_303  feat_304  feat_305  feat_306  \
# 0       458       517       478       482       474       517       482
# 1       462       503       477       492       469       467       475
# 2       460       507       490       500       514       462       481
# 3       458       497       479       483       461       478       484
# 4       534       482       481       472       478       473       491
#
#    feat_307  feat_308  feat_309  feat_310  feat_311  feat_312  feat_313  \
# 0       488       490       485       440       455       464       531
# 1       483       491       464       466       475       477       502
# 2       487       508       466       491       507       494       532
# 3       485       456       504       478       449       489       491
# 4       481       513       473       488       492       500       456
#
#    feat_314  feat_315  feat_316  feat_317  feat_318  feat_319  feat_320  \
# 0       483       467       494       488       414       491       494
# 1       483       506       474       494       469       524       483
# 2       484       489       473       481       506       466       481
# 3       490       463       483       474       458       501       469
# 4       466       421       468       477       462       594       472
#
#    feat_321  feat_322  feat_323  feat_324  feat_325  feat_326  feat_327  \
# 0       497       501       476       481       485       478       476
# 1       434       488       463       495       483       468       481
# 2       386       517       486       479       479       461       507
# 3       479       505       458       503       477       493       481
# 4       459       510       485       477       484       493       509
#
#    feat_328  feat_329  feat_330  feat_331  feat_332  feat_333  feat_334  \
# 0       491       492       523       492       476       464       496
# 1       493       489       538       469       477       480       460
# 2       499       489       481       453       477       485       449
# 3       472       517       516       468       475       529       513
# 4       513       491       535       488       475       488       524
#
#    feat_335  feat_336  feat_337  feat_338  feat_339  feat_340  feat_341  \
# 0       473       658       507       628       484       468       448
# 1       495       469       469       528       544       497       497
# 2       516       465       572       431       531       457       455
# 3       491       398       480       377       463       475       471
# 4       473       385       525       509       471       588       541
#
#    feat_342  feat_343  feat_344  feat_345  feat_346  feat_347  feat_348  \
# 0       502       618       438       486       496       535       452
# 1       462       478       494       481       493       461       482
# 2       540       502       501       489       478       523       513
# 3       510       524       579       466       490       496       525
# 4       475       472       443       475       478       455       460
#
#    feat_349  feat_350  feat_351  feat_352  feat_353  feat_354  feat_355  \
# 0       497       490       485       504       477       481       473
# 1       483       471       422       493       511       471       497
# 2       513       485       511       487       519       509       488
# 3       546       485       390       488       482       512       469
# 4       461       485       400       459       459       503       483
#
#    feat_356  feat_357  feat_358  feat_359  feat_360  feat_361  feat_362  \
# 0       517       476       479       483       482       458       464
# 1       523       476       462       453       471       502       475
# 2       482       475       488       474       509       459       460
# 3       489       476       520       494       498       483       558
# 4       412       477       509       549       547       506       420
#
#    feat_363  feat_364  feat_365  feat_366  feat_367  feat_368  feat_369  \
# 0       466       473       482       497       479       497       495
# 1       536       481       389       491       464       500       553
# 2       481       483       477       494       485       501       475
# 3       483       488       493       466       460       457       447
# 4       464       481       513       482       469       493       538
#
#    feat_370  feat_371  feat_372  feat_373  feat_374  feat_375  feat_376  \
# 0       489       483       500       490       479       471       468
# 1       467       497       489       486       490       540       487
# 2       459       453       513       442       527       457       478
# 3       495       458       506       466       514       519       480
# 4       477       493       523       490       515       497       496
#
#    feat_377  feat_378  feat_379  feat_380  feat_381  feat_382  feat_383  \
# 0       496       419       513       475       471       514       479
# 1       488       526       477       480       462       523       483
# 2       486       464       458       477       479       437       486
# 3       493       553       477       479       486       536       484
# 4       467       424       460       482       482       450       500
#
#    feat_384  feat_385  feat_386  feat_387  feat_388  feat_389  feat_390  \
# 0       480       486       480       477       494       454       480
# 1       488       475       485       479       492       452       479
# 2       498       470       492       479       521       485       480
# 3       485       475       475       476       457       533       474
# 4       502       476       491       476       507       519       478
#
#    feat_391  feat_392  feat_393  feat_394  feat_395  feat_396  feat_397  \
# 0       539       477       441       482       461       484       510
# 1       441       475       442       476       475       484       500
# 2       535       479       505       479       514       495       486
# 3       488       475       431       480       505       481       467
# 4       458       480       455       479       477       479       499
#
#    feat_398  feat_399  feat_400  feat_401  feat_402  feat_403  feat_404  \
# 0       475       485       480       474       474       442       477
# 1       570       482       481       428       477       456       477
# 2       534       477       473       508       477       465       476
# 3       481       477       481       534       477       428       475
# 4       515       483       481       485       476       465       475
#
#    feat_405  feat_406  feat_407  feat_408  feat_409  feat_410  feat_411  \
# 0       502       402       478       504       476       484       475
# 1       546       502       477       516       467       512       469
# 2       466       498       483       487       482       458       523
# 3       443       468       474       478       472       471       493
# 4       467       492       477       491       473       503       465
#
#    feat_412  feat_413  feat_414  feat_415  feat_416  feat_417  feat_418  \
# 0       488       486       524       506       480       451       512
# 1       498       501       503       539       493       505       543
# 2       457       482       506       470       494       435       588
# 3       495       500       457       573       499       466       554
# 4       487       460       509       447       477       496       478
#
#    feat_419  feat_420  feat_421  feat_422  feat_423  feat_424  feat_425  \
# 0       498       478       485       495       476       496       485
# 1       556       486       483       514       476       457       507
# 2       563       487       469       459       476       474       497
# 3       488       480       489       475       476       501       511
# 4       487       473       497       469       476       504       506
#
#    feat_426  feat_427  feat_428  feat_429  feat_430  feat_431  feat_432  \
# 0       496       485       486       482       505       528       496
# 1       475       448       479       481       486       500       489
# 2       480       437       468       478       497       517       435
# 3       466       510       489       483       486       494       477
# 4       501       521       530       479       450       517       478
#
#    feat_433  feat_434  feat_435  feat_436  feat_437  feat_438  feat_439  \
# 0       533       504       512       474       646       526       485
# 1       442       509       479       500       517       489       488
# 2       569       511       505       466       470       465       479
# 3       565       490       507       475       529       478       495
# 4       462       501       475       466       557       437       474
#
#    feat_440  feat_441  feat_442  feat_443  feat_444  feat_445  feat_446  \
# 0       541       487       568       492       467       479       483
# 1       494       496       463       460       472       478       457
# 2       469       480       503       472       490       478       471
# 3       503       486       447       381       489       480       481
# 4       464       487       536       459       517       478       478
#
#    feat_447  feat_448  feat_449  feat_450  feat_451  feat_452  feat_453  \
# 0       479       546       476       457       463       517       471
# 1       487       420       463       484       474       459       311
# 2       492       516       483       506       481       505       606
# 3       497       436       495       469       472       477       545
# 4       469       516       450       490       472       496       426
#
#    feat_454  feat_455  feat_456  feat_457  feat_458  feat_459  feat_460  \
# 0       482       630       481       494       440       509       507
# 1       479       582       480       495       538       487       537
# 2       484       424       484       455       495       503       447
# 3       477       456       480       436       513       485       496
# 4       477       465       482       486       463       491       500
#
#    feat_461  feat_462  feat_463  feat_464  feat_465  feat_466  feat_467  \
# 0       512       496       488       462       498       480       511
# 1       488       485       483       500       487       476       526
# 2       468       513       445       509       492       487       524
# 3       499       472       564       496       481       490       446
# 4       453       528       525       485       492       468       505
#
#    feat_468  feat_469  feat_470  feat_471  feat_472  feat_473  feat_474  \
# 0       500       437       537       470       515       476       467
# 1       449       363       466       478       465       479       482
# 2       479       441       529       481       485       478       479
# 3       486       485       576       481       457       476       481
# 4       476       513       444       476       500       479       483
#
#    feat_475  feat_476  feat_477  feat_478  feat_479  feat_480  feat_481  \
# 0       401       485       499       495       490       508       463
# 1       549       470       506       481       494       492       448
# 2       454       503       501       500       484       479       470
# 3       602       500       503       481       487       465       473
# 4       560       474       486       459       494       509       456
#
#    feat_482  feat_483  feat_484  feat_485  feat_486  feat_487  feat_488  \
# 0       487       531       515       476       482       463       467
# 1       492       447       598       507       478       483       492
# 2       466       529       482       486       487       480       522
# 3       477       515       525       468       487       458       489
# 4       472       520       468       482       473       473       498
#
#    feat_489  feat_490  feat_491  feat_492  feat_493  feat_494  feat_495  \
# 0       479       477       481       477       485       511       485
# 1       485       463       478       487       338       513       486
# 2       481       487       481       492       650       506       501
# 3       490       491       480       474       572       454       469
# 4       485       488       479       452       435       486       508
#
#    feat_496  feat_497  feat_498  feat_499  label
# 0       481       479       475       496     -1
# 1       483       492       510       517     -1
# 2       480       489       499       498     -1
# 3       475       482       494       461      1
# 4       481       504       495       511      1

# %%
madelon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Columns: 502 entries, index to label
# dtypes: int64(502)
# memory usage: 7.7 MB

# %%
madelon_df.shape
# Out:
# (2000, 502)

# %% [markdown]
# **Creating our target vector**

# %%
y = madelon_df['label']

# %%
# target vector is comprised of '1's and '-1's

y.unique()
# Out:
# array([-1,  1])

# %%
# the target vector is evenly distributed

y.value_counts()
# Out:
#  1    1000
# -1    1000
# Name: label, dtype: int64

# %% [markdown]
# **Creating the feature matrix**

# %%
X = madelon_df.drop(['label', 'index'], axis=1)
X.head(1)
# Out:
#    feat_000  feat_001  feat_002  feat_003  feat_004  feat_005  feat_006  \
# 0       485       477       537       479       452       471       491
#
#    feat_007  feat_008  feat_009  feat_010  feat_011  feat_012  feat_013  \
# 0       476       475       473       455       500       456       507
#
#    feat_014  feat_015  feat_016  feat_017  feat_018  feat_019  feat_020  \
# 0       478       491       447       422       480       482       515
#
#    feat_021  feat_022  feat_023  feat_024  feat_025  feat_026  feat_027  \
# 0       482       464       484       477       496       509       491
#
#    feat_028  feat_029  feat_030  feat_031  feat_032  feat_033  feat_034  \
# 0       459       482       483       505       508       458       509
#
#    feat_035  feat_036  feat_037  feat_038  feat_039  feat_040  feat_041  \
# 0       517       479       487       473       472       474       531
#
#    feat_042  feat_043  feat_044  feat_045  feat_046  feat_047  feat_048  \
# 0       485       508       517       489       507       515       440
#
#    feat_049  feat_050  feat_051  feat_052  feat_053  feat_054  feat_055  \
# 0       465       550       532       450       483       460       469
#
#    feat_056  feat_057  feat_058  feat_059  feat_060  feat_061  feat_062  \
# 0       507       485       479       458       516       480       460
#
#    feat_063  feat_064  feat_065  feat_066  feat_067  feat_068  feat_069  \
# 0       479       648       480       561       481       474       474
#
#    feat_070  feat_071  feat_072  feat_073  feat_074  feat_075  feat_076  \
# 0       544       484       490       451       494       480       486
#
#    feat_077  feat_078  feat_079  feat_080  feat_081  feat_082  feat_083  \
# 0       459       521       500       466       457       494       492
#
#    feat_084  feat_085  feat_086  feat_087  feat_088  feat_089  feat_090  \
# 0       488       497       477       461       473       464       476
#
#    feat_091  feat_092  feat_093  feat_094  feat_095  feat_096  feat_097  \
# 0       471       481       507       474       500       481       536
#
#    feat_098  feat_099  feat_100  feat_101  feat_102  feat_103  feat_104  \
# 0       464       501       479       480       483       462       470
#
#    feat_105  feat_106  feat_107  feat_108  feat_109  feat_110  feat_111  \
# 0       181       510       470       431       482       496       481
#
#    feat_112  feat_113  feat_114  feat_115  feat_116  feat_117  feat_118  \
# 0       469       539       491       482       481       476       533
#
#    feat_119  feat_120  feat_121  feat_122  feat_123  feat_124  feat_125  \
# 0       495       474       485       479       495       465       541
#
#    feat_126  feat_127  feat_128  feat_129  feat_130  feat_131  feat_132  \
# 0       493       488       452       481       491       501       477
#
#    feat_133  feat_134  feat_135  feat_136  feat_137  feat_138  feat_139  \
# 0       479       503       529       540       504       482       463
#
#    feat_140  feat_141  feat_142  feat_143  feat_144  feat_145  feat_146  \
# 0       477       530       508       488       488       474       479
#
#    feat_147  feat_148  feat_149  feat_150  feat_151  feat_152  feat_153  \
# 0       506       478       511       501       474       483       575
#
#    feat_154  feat_155  feat_156  feat_157  feat_158  feat_159  feat_160  \
# 0       478       482       461       480       543       415       527
#
#    feat_161  feat_162  feat_163  feat_164  feat_165  feat_166  feat_167  \
# 0       477       487       486       511       474       477       482
#
#    feat_168  feat_169  feat_170  feat_171  feat_172  feat_173  feat_174  \
# 0       476       516       466       492       561       479       472
#
#    feat_175  feat_176  feat_177  feat_178  feat_179  feat_180  feat_181  \
# 0       457       497       475       452       491       477       454
#
#    feat_182  feat_183  feat_184  feat_185  feat_186  feat_187  feat_188  \
# 0       461       472       481       490       526       490       459
#
#    feat_189  feat_190  feat_191  feat_192  feat_193  feat_194  feat_195  \
# 0       478       461       516       511       544       519       487
#
#    feat_196  feat_197  feat_198  feat_199  feat_200  feat_201  feat_202  \
# 0       485       475       477       476       478       470       493
#
#    feat_203  feat_204  feat_205  feat_206  feat_207  feat_208  feat_209  \
# 0       581       484       476       521       474       492       459
#
#    feat_210  feat_211  feat_212  feat_213  feat_214  feat_215  feat_216  \
# 0       487       504       464       485       478       465       603
#
#    feat_217  feat_218  feat_219  feat_220  feat_221  feat_222  feat_223  \
# 0       475       481       491       555       424       528       511
#
#    feat_224  feat_225  feat_226  feat_227  feat_228  feat_229  feat_230  \
# 0       384       525       459       478       477       539       479
#
#    feat_231  feat_232  feat_233  feat_234  feat_235  feat_236  feat_237  \
# 0       508       471       517       482       518       473       478
#
#    feat_238  feat_239  feat_240  feat_241  feat_242  feat_243  feat_244  \
# 0       506       476       507       434       466       480       547
#
#    feat_245  feat_246  feat_247  feat_248  feat_249  feat_250  feat_251  \
# 0       518       516       476       492       454       463       497
#
#    feat_252  feat_253  feat_254  feat_255  feat_256  feat_257  feat_258  \
# 0       477       531       472       495       532       496       492
#
#    feat_259  feat_260  feat_261  feat_262  feat_263  feat_264  feat_265  \
# 0       480       480       479       517       470       470       500
#
#    feat_266  feat_267  feat_268  feat_269  feat_270  feat_271  feat_272  \
# 0       468       477       486       553       490       499       450
#
#    feat_273  feat_274  feat_275  feat_276  feat_277  feat_278  feat_279  \
# 0       469       466       479       476       401       491       551
#
#    feat_280  feat_281  feat_282  feat_283  feat_284  feat_285  feat_286  \
# 0       477       517       492       475       537       516       472
#
#    feat_287  feat_288  feat_289  feat_290  feat_291  feat_292  feat_293  \
# 0       451       484       471       469       523       496       482
#
#    feat_294  feat_295  feat_296  feat_297  feat_298  feat_299  feat_300  \
# 0       458       487       477       457       458       493       458
#
#    feat_301  feat_302  feat_303  feat_304  feat_305  feat_306  feat_307  \
# 0       517       478       482       474       517       482       488
#
#    feat_308  feat_309  feat_310  feat_311  feat_312  feat_313  feat_314  \
# 0       490       485       440       455       464       531       483
#
#    feat_315  feat_316  feat_317  feat_318  feat_319  feat_320  feat_321  \
# 0       467       494       488       414       491       494       497
#
#    feat_322  feat_323  feat_324  feat_325  feat_326  feat_327  feat_328  \
# 0       501       476       481       485       478       476       491
#
#    feat_329  feat_330  feat_331  feat_332  feat_333  feat_334  feat_335  \
# 0       492       523       492       476       464       496       473
#
#    feat_336  feat_337  feat_338  feat_339  feat_340  feat_341  feat_342  \
# 0       658       507       628       484       468       448       502
#
#    feat_343  feat_344  feat_345  feat_346  feat_347  feat_348  feat_349  \
# 0       618       438       486       496       535       452       497
#
#    feat_350  feat_351  feat_352  feat_353  feat_354  feat_355  feat_356  \
# 0       490       485       504       477       481       473       517
#
#    feat_357  feat_358  feat_359  feat_360  feat_361  feat_362  feat_363  \
# 0       476       479       483       482       458       464       466
#
#    feat_364  feat_365  feat_366  feat_367  feat_368  feat_369  feat_370  \
# 0       473       482       497       479       497       495       489
#
#    feat_371  feat_372  feat_373  feat_374  feat_375  feat_376  feat_377  \
# 0       483       500       490       479       471       468       496
#
#    feat_378  feat_379  feat_380  feat_381  feat_382  feat_383  feat_384  \
# 0       419       513       475       471       514       479       480
#
#    feat_385  feat_386  feat_387  feat_388  feat_389  feat_390  feat_391  \
# 0       486       480       477       494       454       480       539
#
#    feat_392  feat_393  feat_394  feat_395  feat_396  feat_397  feat_398  \
# 0       477       441       482       461       484       510       475
#
#    feat_399  feat_400  feat_401  feat_402  feat_403  feat_404  feat_405  \
# 0       485       480       474       474       442       477       502
#
#    feat_406  feat_407  feat_408  feat_409  feat_410  feat_411  feat_412  \
# 0       402       478       504       476       484       475       488
#
#    feat_413  feat_414  feat_415  feat_416  feat_417  feat_418  feat_419  \
# 0       486       524       506       480       451       512       498
#
#    feat_420  feat_421  feat_422  feat_423  feat_424  feat_425  feat_426  \
# 0       478       485       495       476       496       485       496
#
#    feat_427  feat_428  feat_429  feat_430  feat_431  feat_432  feat_433  \
# 0       485       486       482       505       528       496       533
#
#    feat_434  feat_435  feat_436  feat_437  feat_438  feat_439  feat_440  \
# 0       504       512       474       646       526       485       541
#
#    feat_441  feat_442  feat_443  feat_444  feat_445  feat_446  feat_447  \
# 0       487       568       492       467       479       483       479
#
#    feat_448  feat_449  feat_450  feat_451  feat_452  feat_453  feat_454  \
# 0       546       476       457       463       517       471       482
#
#    feat_455  feat_456  feat_457  feat_458  feat_459  feat_460  feat_461  \
# 0       630       481       494       440       509       507       512
#
#    feat_462  feat_463  feat_464  feat_465  feat_466  feat_467  feat_468  \
# 0       496       488       462       498       480       511       500
#
#    feat_469  feat_470  feat_471  feat_472  feat_473  feat_474  feat_475  \
# 0       437       537       470       515       476       467       401
#
#    feat_476  feat_477  feat_478  feat_479  feat_480  feat_481  feat_482  \
# 0       485       499       495       490       508       463       487
#
#    feat_483  feat_484  feat_485  feat_486  feat_487  feat_488  feat_489  \
# 0       531       515       476       482       463       467       479
#
#    feat_490  feat_491  feat_492  feat_493  feat_494  feat_495  feat_496  \
# 0       477       481       477       485       511       485       481
#
#    feat_497  feat_498  feat_499
# 0       479       475       496

# %% [markdown]
# **Confirming that our target vector and feature matrix have the appropriate shapes for sklearn**

# %%
X.shape, y.shape
# Out:
# ((2000, 500), (2000,))

# %% [markdown]
# **Making data dictionary**

# %%
madelon_data_dict = make_data_dict(X, y, 0.25, 82)

# %% [markdown]
# **Confirming the Train-Test-Split**

# %%
pd.DataFrame(madelon_data_dict['X_train']).shape
# Out:
# (1500, 500)

# %%
pd.DataFrame(madelon_data_dict['X_test']).shape
# Out:
# (500, 500)

# %% [markdown]
# **Standard Scaler**

# %%
madelon_scaled_dict = general_transformer(StandardScaler(), madelon_data_dict)

# %%
madelon_data_dict['processes']
# Out:
# [StandardScaler(copy=True, with_mean=True, with_std=True)]

# %%
scaler = madelon_scaled_dict['transformer']
scaler
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
scaler.mean_
# Out:
# array([ 481.688     ,  483.64066667,  511.44533333,  483.40933333,
#         501.95666667,  479.336     ,  479.81266667,  476.52933333,
#         486.79133333,  478.574     ,  486.248     ,  490.96533333,
#         478.74133333,  482.70666667,  485.17133333,  479.906     ,
#         479.16266667,  494.94533333,  483.51066667,  477.47333333,
#         484.47666667,  494.24733333,  476.426     ,  479.38733333,
#         500.00666667,  504.08333333,  484.518     ,  482.242     ,
#         480.548     ,  491.65733333,  481.92666667,  499.77333333,
#         500.84733333,  490.66333333,  486.40866667,  489.25      ,
#         479.28866667,  480.64666667,  479.73333333,  476.12266667,
#         476.49666667,  489.59666667,  476.30466667,  487.72933333,
#         500.57466667,  480.58      ,  496.20933333,  494.418     ,
#         485.254     ,  479.01733333,  517.442     ,  504.33866667,
#         484.84933333,  479.952     ,  496.92733333,  494.98133333,
#         480.36933333,  485.288     ,  509.16133333,  477.61933333,
#         488.198     ,  481.54866667,  493.63533333,  478.7       ,
#         499.35533333,  511.04133333,  503.72133333,  490.49533333,
#         480.94933333,  476.18666667,  514.46666667,  488.558     ,
#         481.28266667,  484.40066667,  480.59266667,  501.868     ,
#         478.98      ,  483.65133333,  512.93666667,  482.49      ,
#         490.49533333,  512.02066667,  483.506     ,  482.27066667,
#         504.04733333,  488.56533333,  477.06      ,  482.908     ,
#         479.25933333,  512.758     ,  476.04066667,  507.60733333,
#         479.43333333,  492.458     ,  480.40133333,  497.918     ,
#         479.27666667,  479.462     ,  477.08333333,  480.83066667,
#         479.94266667,  480.69933333,  480.99733333,  477.88333333,
#         483.84333333,  500.27533333,  484.49933333,  490.61533333,
#         500.28      ,  480.98333333,  487.78466667,  478.106     ,
#         477.19733333,  492.512     ,  479.22866667,  478.78333333,
#         489.04066667,  482.75133333,  496.37733333,  488.598     ,
#         476.13133333,  478.90666667,  480.58066667,  482.046     ,
#         478.75266667,  504.81133333,  483.35733333,  499.204     ,
#         478.96133333,  483.46      ,  501.23466667,  486.122     ,
#         487.64      ,  477.59666667,  484.668     ,  503.26733333,
#         498.53533333,  491.36533333,  479.63466667,  483.136     ,
#         493.02266667,  508.22533333,  482.10533333,  483.38266667,
#         483.026     ,  487.06933333,  479.84266667,  497.29666667,
#         480.02733333,  497.138     ,  487.98133333,  483.86066667,
#         482.02533333,  501.61266667,  476.94      ,  486.89066667,
#         483.62333333,  477.88333333,  499.276     ,  499.76933333,
#         478.19933333,  478.56466667,  481.22266667,  479.982     ,
#         489.06266667,  487.27466667,  476.03666667,  479.13666667,
#         476.866     ,  511.44      ,  494.60333333,  510.146     ,
#         507.03266667,  477.09866667,  476.496     ,  500.18066667,
#         482.878     ,  480.432     ,  483.86666667,  505.904     ,
#         503.46866667,  514.38533333,  476.67066667,  478.524     ,
#         488.24466667,  487.26533333,  497.33866667,  492.54666667,
#         517.774     ,  478.45333333,  481.888     ,  490.59466667,
#         495.784     ,  506.382     ,  513.25933333,  484.09733333,
#         479.21733333,  483.20666667,  476.48866667,  486.16866667,
#         490.86666667,  488.426     ,  489.66266667,  507.99933333,
#         488.086     ,  476.04933333,  506.38733333,  479.11333333,
#         481.26266667,  490.58533333,  487.598     ,  492.34733333,
#         480.51533333,  488.424     ,  480.31666667,  503.218     ,
#         504.15533333,  480.63266667,  487.31933333,  485.052     ,
#         478.81666667,  498.9       ,  493.416     ,  487.928     ,
#         493.38466667,  500.48      ,  485.02933333,  477.52866667,
#         476.36333333,  493.88066667,  479.85266667,  482.27266667,
#         478.52533333,  484.126     ,  491.32266667,  496.31266667,
#         483.10666667,  478.05      ,  475.66266667,  478.06733333,
#         497.254     ,  498.396     ,  490.16      ,  479.304     ,
#         507.95066667,  510.78133333,  477.84466667,  479.138     ,
#         481.80133333,  499.14066667,  489.924     ,  494.246     ,
#         476.88733333,  508.28      ,  478.32066667,  492.21266667,
#         499.58466667,  490.97      ,  485.49866667,  485.68266667,
#         490.838     ,  478.55      ,  494.16133333,  484.146     ,
#         479.03466667,  494.184     ,  501.076     ,  489.34066667,
#         484.73266667,  492.50266667,  483.98733333,  499.51666667,
#         484.35466667,  487.02666667,  476.73866667,  484.42533333,
#         476.16933333,  495.58066667,  495.92533333,  493.09733333,
#         476.884     ,  479.466     ,  481.94666667,  476.03533333,
#         504.17733333,  491.186     ,  478.39066667,  483.91666667,
#         479.72733333,  493.268     ,  491.45133333,  503.81066667,
#         496.40866667,  476.29266667,  485.71466667,  497.82666667,
#         475.20333333,  501.00733333,  497.27533333,  496.22533333,
#         481.562     ,  489.69133333,  477.96066667,  491.558     ,
#         494.34466667,  485.75333333,  480.448     ,  480.82866667,
#         499.16333333,  476.32733333,  486.31466667,  480.12066667,
#         500.76133333,  499.51      ,  480.98      ,  487.61133333,
#         477.474     ,  481.19466667,  486.20866667,  511.552     ,
#         483.176     ,  483.36466667,  490.53866667,  480.35266667,
#         489.854     ,  480.05066667,  482.48      ,  482.35266667,
#         486.362     ,  515.292     ,  487.28333333,  479.21066667,
#         476.15466667,  488.05733333,  495.828     ,  487.788     ,
#         482.06533333,  487.51133333,  501.602     ,  501.00866667,
#         506.15466667,  493.742     ,  496.19533333,  502.842     ,
#         499.69      ,  482.78133333,  481.38666667,  490.21666667,
#         481.14333333,  503.85933333,  481.358     ,  478.43      ,
#         484.42333333,  482.27333333,  493.432     ,  484.59933333,
#         502.87666667,  476.534     ,  506.578     ,  498.5       ,
#         482.98333333,  491.082     ,  478.186     ,  486.222     ,
#         480.89266667,  494.91      ,  495.53266667,  483.72066667,
#         484.468     ,  499.636     ,  487.61266667,  490.04866667,
#         497.30266667,  487.60466667,  501.018     ,  491.53733333,
#         480.41866667,  483.44266667,  496.462     ,  481.53133333,
#         480.884     ,  479.252     ,  496.966     ,  483.96666667,
#         479.864     ,  478.14733333,  492.27666667,  477.20133333,
#         494.9       ,  484.04      ,  476.826     ,  493.16533333,
#         476.39733333,  486.92066667,  478.098     ,  484.28266667,
#         484.19466667,  482.50266667,  510.644     ,  481.24733333,
#         476.99333333,  488.90333333,  476.05466667,  487.47466667,
#         476.64266667,  477.19      ,  481.77866667,  477.90333333,
#         483.20266667,  478.12866667,  489.77666667,  490.5       ,
#         488.19866667,  484.06733333,  492.348     ,  517.50933333,
#         484.17533333,  506.98133333,  510.858     ,  496.908     ,
#         480.47266667,  478.93066667,  477.76533333,  476.05866667,
#         485.03733333,  489.122     ,  490.35866667,  484.69933333,
#         483.966     ,  476.91533333,  493.514     ,  505.48533333,
#         479.41066667,  498.504     ,  489.03266667,  499.82666667,
#         477.46733333,  516.87533333,  484.752     ,  485.00733333,
#         490.53733333,  479.76733333,  495.82533333,  502.00533333,
#         492.81333333,  477.232     ,  479.628     ,  486.18066667,
#         484.188     ,  476.402     ,  487.82333333,  477.54266667,
#         489.414     ,  481.006     ,  479.84      ,  502.994     ,
#         479.71      ,  481.85      ,  491.18933333,  485.418     ,
#         503.222     ,  483.192     ,  493.56533333,  480.532     ,
#         485.39533333,  490.75      ,  480.70266667,  511.02066667,
#         481.54      ,  481.63      ,  515.904     ,  478.73666667,
#         480.49466667,  477.628     ,  479.37733333,  485.80133333,
#         481.46933333,  487.944     ,  483.22466667,  486.79533333,
#         485.45333333,  478.378     ,  477.046     ,  497.43866667,
#         502.51533333,  482.84866667,  478.63533333,  483.432     ,
#         489.878     ,  479.63866667,  482.54266667,  478.75      ,
#         486.15133333,  495.59      ,  494.02266667,  510.23666667,
#         478.2       ,  482.94      ,  507.65666667,  490.04866667])

# %% [markdown]
# ## Test of General Model - Logistic Regression

# %%
log_reg_dict = general_model(LogisticRegression(C=1E10, penalty='l1', n_jobs=-1), madelon_scaled_dict)

# %%
log_reg_dict['processes']
# Out:
# [StandardScaler(copy=True, with_mean=True, with_std=True),
#  LogisticRegression(C=10000000000.0, class_weight=None, dual=False,
#            fit_intercept=True, intercept_scaling=1, max_iter=100,
#            multi_class='ovr', n_jobs=-1, penalty='l1', random_state=None,
#            solver='liblinear', tol=0.0001, verbose=0, warm_start=False)]

# %%
log_reg_dict['model']
# Out:
# LogisticRegression(C=10000000000.0, class_weight=None, dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=-1, penalty='l1', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)

# %% [markdown]
# ### Getting a Benchmark Score
#
# Train and Test Score from "out-of-the-box" Logistic Regression
# - no Regularlization (C=1E10)

# %%
print("Train Score: {:.4f}".format(log_reg_dict['train_score']))
print("Test Score:  {:.4f}".format(log_reg_dict['test_score']))
# Out:
# Train Score: 0.7953
# Test Score:  0.5280

# %% [markdown]
# **Examining the coefficients from Logistic Regression**

# %%
log_reg_coef_df = pd.DataFrame({'coef': log_reg_dict['model'].coef_[0],
                                'variable': X.columns,
                                'abscoef': np.abs(log_reg_dict['model'].coef_[0])
                               })

log_reg_coef_df.sort_values('abscoef', ascending=False, inplace=True)
log_reg_coef_df.head(5)
# Out:
#      abscoef     coef  variable
# 475  1.95810  1.95810  feat_475
# 48   1.76535  1.76535  feat_048
# 442  1.66531 -1.66531  feat_442
# 318  1.49359 -1.49359  feat_318
# 281  1.43271 -1.43271  feat_281

# %%
log_reg_coef_df.shape
# Out:
# (500, 3)

# %%
# confirm all features retained -- no regularization given C=1E10

log_reg_coef_df[log_reg_coef_df['coef'] != 0].shape
# Out:
# (500, 3)

# %% [markdown]
# ## Pipeline 2 - Identifying Features via Lasso

# %%
madelon_scaled_dict_copy = madelon_scaled_dict

# %%
C_list = [0.0001, 0.01, 0.015, 0.020, 0.0225, 0.025, 0.03, 0.035, 0.04, 0.05, 0.1, 0.125, 0.15, 0.25, 0.5, 1000, 10000, 1000000]

# %%
def results(model_C, dictionary1):
    
    log_reg_tdict = general_model(model_C, madelon_scaled_dict_copy)
    
    return {'C': C,
            'train_score': dictionary1['train_score'],
            'test_score' : dictionary1['test_score'],
            'non_zero_coefs': np.count_nonzero(log_reg_tdict['model'].coef_[0])
           }

# %%
results_output = [results(LogisticRegression(C=C, penalty='l1', n_jobs=-1), madelon_scaled_dict_copy)
                  for C in C_list]


results_output_df = pd.DataFrame(results_output)
results_output_df.sort_values('C', ascending=False, inplace=True)
results_output_df
# Out:
#                C  non_zero_coefs  test_score  train_score
# 17  1000000.0000             500       0.528      0.79533
# 16    10000.0000             500       0.526      0.79467
# 15     1000.0000             500       0.528      0.79533
# 14        0.5000             438       0.536      0.77000
# 13        0.2500             392       0.540      0.76067
# 12        0.1500             330       0.556      0.75867
# 11        0.1250             302       0.574      0.75000
# 10        0.1000             265       0.586      0.74867
# 9         0.0500             125       0.576      0.69000
# 8         0.0400              74       0.572      0.66400
# 7         0.0350              53       0.582      0.65400
# 6         0.0300              39       0.612      0.64333
# 5         0.0250              15       0.620      0.63600
# 4         0.0225              10       0.612      0.63133
# 3         0.0200               5       0.616      0.62600
# 2         0.0150               2       0.610      0.62200
# 1         0.0100               1       0.606      0.61800
# 0         0.0001               0       0.486      0.50467

# %%
graph_df = results_output_df[results_output_df['C']<=0.05]
graph_df
# Out:
#         C  non_zero_coefs  test_score  train_score
# 9  0.0500             125       0.576      0.69000
# 8  0.0400              74       0.572      0.66400
# 7  0.0350              53       0.582      0.65400
# 6  0.0300              39       0.612      0.64333
# 5  0.0250              15       0.620      0.63600
# 4  0.0225              10       0.612      0.63133
# 3  0.0200               5       0.616      0.62600
# 2  0.0150               2       0.610      0.62200
# 1  0.0100               1       0.606      0.61800
# 0  0.0001               0       0.486      0.50467

# %%
plt.plot(graph_df['C'], graph_df['test_score'], label='test score')
plt.plot(graph_df['C'], graph_df['train_score'], label='training score')
plt.legend()

# %%
plt.plot(graph_df['C'], graph_df['non_zero_coefs'], label='non_zero_coefs')
plt.legend()

# %%
fsdfsfsdf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-3b250072d1e7> in <module>()
# ----> 1 fsdfsfsdf
#
# NameError: name 'fsdfsfsdf' is not defined

# %%
results = {}

for C in C_list:
    
    log_reg_tdict = general_model(LogisticRegression(C=C, penalty='l1', n_jobs=-1), madelon_scaled_dict_copy)
    results['C'] = C
    results['train_score'] = madelon_scaled_dict_copy['train_score']
    results['test_score'] = madelon_scaled_dict_copy['test_score']
    results['non_zero_coefs'] = np.count_nonzero(log_reg_tdict['model'].coef_[0])

    print (results)

# %%
# general_model(LogisticRegression(C=C, penalty='l1', n_jobs=-1), madelon_scaled_dict_copy)

# %%
sdsdadasdasda

# %%
log_reg_dict1 = general_model(LogisticRegression(C=0.0001, penalty='l1', n_jobs=-1), madelon_scaled_dict_copy)

# %%
log_reg_dict1['processes']

# %%
log_reg_dict1['model']

# %%
print("Train Score: {:.4f}".format(log_reg_dict1['train_score']))
print("Test Score:  {:.4f}".format(log_reg_dict1['test_score']))

# %% [markdown]
# **Examining the Impact of Increasing Regularization on Coefficients -- Feature Selection**

# %%
log_reg_coef1_df = pd.DataFrame({'coef': log_reg_dict1['model'].coef_[0],
                                 'variable': X.columns,
                                 'abscoef': np.abs(log_reg_dict1['model'].coef_[0])
                                })

log_reg_coef1_df.sort_values('abscoef', ascending=False, inplace=True)
log_reg_coef1_df.head(5)

# %%
lasso_features_removed = log_reg_coef1_df[log_reg_coef1_df['coef'] == 0]
lasso_features_removed.count()

# %%
# Baseline Values: Train: 0.7953, Test: 0.5280

# %%
# C=1: Train: 0.7767, Test: 0.5280 -- 31 features removed

# %%
# C=0.1: Train: 0.7487, Test: 0.5860 -- 235 features removed

# %%
# C=0.01: Train: 0.6180, Test: 0.6060 -- 499 features removed

# %%
# C=0.055: Train: 0.7013, Test: 0.5780 -- 349 features removed -- split the difference between the last case

# %%
# C=0.0001: Train: 0.5047, Test: 0.4860 -- effectively all of the features removed

# %%
results = [general_model(LogisticRegression(C=C, penalty='l1', n_jobs=-1), madelon_scaled_dict_copy) \
           for C in C_list]

# %%
results
